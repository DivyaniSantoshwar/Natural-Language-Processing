# %%
import cv2 
import matplotlib.pyplot as plt 
import numpy as np

# %%
img = cv2.imread("images/lenna.png", 0  )

# %%
binary_image = img > 135

# %%
plt.figure(figsize=(10,6))
plt.subplot(121) , plt.imshow(img, cmap="gray") , plt.title("Original Image")
plt.subplot(122) , plt.imshow(binary_image, cmap="gray") , plt.title("Binary Image")
plt.show()

# %%
binary_image.dtype
# Out:
# dtype('bool')

# %%
binary_image= binary_image.astype(np.uint8)*255

# %%
## Show original & smoothed images
cv2.imshow("Original" , img)
cv2.imshow("Smoothed" , binary_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
binary_image
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255]], dtype=uint8)

# %% [markdown]
# ### Inverse Binary Thresholding

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#Load the image 
image =cv2.imread("images/lenna.png",0)

#Define a threshold value 
binary_image = image < 150

# %%
## Show the original & binary images

plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(img, cmap="gray") 
plt.title("Original Image")
plt.subplot(122) 
plt.imshow(binary_image, cmap="gray") 
plt.title("Inverse Binary Image")
plt.show()

# %%
ret, thresh1 = cv2.threshold(image, 120,255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(image, 120,255, cv2.THRESH_BINARY_INV)

plt.figure(figsize=(16,8))
plt.subplot(1,3,1) 
plt.title("Original Image")
plt.imshow(img, cmap="gray")
plt.subplot(1,3,2)
plt.title("Binary Image")
plt.imshow(thresh1, cmap="gray") 
plt.subplot(1,3,3) 
plt.title("Inverse Binary Image")
plt.imshow(thresh2, cmap='gray')
